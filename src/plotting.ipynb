# %%
import sys 
sys.path.append('../imports/')

from plotter import *
import numpy as np 
from matplotlib import pyplot as plt

# %%
tag = 'ICNN_MSE_H2'
predict = np.load(f'../output/{tag}_predict_data.npz')
true_dat = np.load(f'../output/{tag}_true_data.npz')

# %%
truth_plot(true_dat['stress'], predict['stress'], nrows=2, ncols=3, scatter_pts=True, subtitle='Str')

# %%
truth_plot(extract_symm(true_dat['stiffness']), extract_symm(predict['stiffness']),
             nrows=3, ncols=7, scatter_pts=True, figsize = (12, 9), subtitle='Stiff')

# %%
eng_true = true_dat['energy'].reshape(-1, 1)
eng_pred = predict['energy'].reshape(-1, 1)

# %%
true_dat['stiffness'].shape
# Out:
# (18318, 6, 6)

# %%
plt.hist(true_dat['stiffness'][:, 1, 1], histtype='step', label = 'True', density=True, bins =100)
plt.hist(predict['stiffness'][:, 1, 1], histtype='step', label = 'Predict', density=True, bins =100)
plt.legend()

# %%
plt.hist(true_dat['energy'], histtype='step', label = 'True', density=True, bins =100)
plt.hist(predict['energy'], histtype='step', label = 'Predict', density=True, bins =100)
plt.legend()
plt.xlabel('Energy')
plt.ylabel('Density')
# Out:
# Text(0, 0.5, 'Density')

# %%
truth_plot(true_dat['energy'], predict['energy'], nrows=1, ncols=1, scatter_pts=True, subtitle='Eng')
